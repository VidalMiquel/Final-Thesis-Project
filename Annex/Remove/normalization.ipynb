# %%
import pickle
import networkx as nx
import pandas as pd

# %%
individualMetricsBarcelona = "../Data/Barcelona/04Stage/Metrics/Individual/IndividualnetworkMetrics.pkl"

# %%
def load_metrics(file):
    try:
        with open(file, "rb") as f:
            deserializedFile = pickle.load(f)
        return deserializedFile
    except FileNotFoundError:
        print(f"File '{individualMetricsBarcelona}' not found.")
    except nx.NetworkXError as e:
        print(f"Error reading graph from '{individualMetricsBarcelona}': {e}")

# %%
individualMetricsBarcelonaFile = load_metrics(individualMetricsBarcelona)

# %%
def normalize_list(lst):
    max_val = max(lst)
    min_val = min(lst)
    if max_val == min_val:
        # Handle case where all values are the same
        return [0] * len(lst)
    return [(x - min_val) / (max_val - min_val) for x in lst]

# %%
def calculateMetrics(data):
    dfNoNan = data.fillna(" ")
    dfNoBlank = dfNoNan.replace(" ", float('NaN'))  # Replace blank spaces with 0

    # Calculate mean, standard deviation, and count
    meanValues = dfNoBlank.mean(axis=1).round(2)
    stdValues = dfNoBlank.std(axis=1).round(2)
    countValues = dfNoBlank.count(axis=1)

    return meanValues, stdValues, countValues

# %%
finalDict = {}
for element in individualMetricsBarcelonaFile:
    metricsTable = pd.DataFrame()
    concatenated_dict = {}
    for score in individualMetricsBarcelonaFile[element]:
        #print(individualMetricsBarcelonaFile[element][socre])
        #print(score)
        df = pd.DataFrame.from_dict(individualMetricsBarcelonaFile[element][score], orient='index')

        dfN = (df - df.min()) / (df.max() - df.min())
        #meanValues, stdValues, countValues = calculateMetrics(dfN)
        #metricsTable = pd.concat([metricsTable, meanValues.rename('Mean'), stdValues.rename('Std'), countValues.rename('Count')], axis=1)
        #print(metricsTable)
        dfN.set_index(df.index, inplace=True)
        #print(dfN.T)
        a = dfN.T.to_dict(orient='list')
        concatenated_dict[score] = a
    #print(concatenated_dict)
    finalDict[element] = concatenated_dict
print(finalDict)
# Out:
# {'inD': {'0_1': {'6616': [0.125, 0.6666666666666666, nan, nan, nan, nan, nan, nan, nan], '5503': [0.375, 0.6666666666666666, 0.3333333333333333, 0.0, 0.5714285714285714, nan, nan, nan, nan], '5203': [0.875, 0.4444444444444444, 0.8333333333333334, 0.5714285714285714, 1.0, 0.75, 0.6666666666666666, 0.0, nan], '6379': [0.375, 0.4444444444444444, 0.6666666666666666, 0.7142857142857143, 0.7142857142857143, 0.25, 0.8333333333333334, nan, nan], '5506': [0.375, 0.4444444444444444, 1.0, 0.2857142857142857, 0.5714285714285714, 0.5, 0.6666666666666666, nan, nan], '4691': [0.25, 0.4444444444444444, 0.0, 0.14285714285714285, 0.0, 0.0, 0.0, nan, nan], '4324': [0.0, 0.4444444444444444, 0.3333333333333333, 0.2857142857142857, 0.5714285714285714, nan, nan, nan, nan], '4320': [0.375, 0.5555555555555556, 0.8333333333333334, 0.5714285714285714, 1.0, 1.0, 0.6666666666666666, 0.0, nan], '5213': [0.375, 0.6666666666666666, 0.16666666666666666, 0.8571428571428571, 0.2857142857142857, 0.25, 1.0, 1.0, nan], '
# ...
